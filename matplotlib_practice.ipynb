# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "Apr", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]


# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.2, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %% [markdown]
# # Create Line Chart using the MATLAB Method

# %%
# Create the plot
# chain the plot() function to plt. Inside the parentheses of the plot() function, add the x_axis and y_axis parameters

plt.plot(x_axis, y_axis)

# %% [markdown]
# # Create Line Chart using Object Oriented Method

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %% [markdown]
# ## Another way to create the same chart using the Object Oriented Method

# %%
# The fig, ax = plt.subplots() line of code can also be written like this.
#Create the plot with ax.plt()
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_axis, y_axis)

# %% [markdown]
# ### Another quick way to create the line chart with the Object Oriented Method

# %%
# Using the object oriented method to: Create the plot with ax.plt()
ax = plt.axes()
ax.plot(x_axis, y_axis)

# %% [markdown]
# # Adding color, line width, and a marker unsing Matplolib

# %%
# Create the plot, add a label for the legend, adding a line color, line width, and a marker for our data points.
plt.plot(x_axis, y_axis, label='Boston')
plt.plot(x_axis, y_axis, marker="*", color="blue", linewidth=2, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")

# Set the y limit between 0 and 45.
plt.ylim(0, 45)

# Create a title.
plt.title("PyBer Fare by Month")

# Add a grid.
plt.grid()

# Add the legend.
plt.legend()

# %% [markdown]
# ### Skill Drill
#
# Using the object-oriented approach, make the following changes to your line chart:
#
# • Change the line color to green.
#
# • Change the marker to a diamond.
#
# • Change the line width to 2 points.
#
# • Add a legend for the city of Boston.
#
# • Add a title and axes labels.
#
# • Add a y-axis limit.
#
# • Add grid lines.

# %%
# Create the plot using the object-oriented approach.

ax = plt.axes()
#1.Change the line color to green.
#2.Change the marker to a diamond.
#3.Change the line width to 2 points.
#4.Add a legend for the city of Boston.
ax.plot(x_axis, y_axis, marker='D', color='green', linewidth=2, label='Boston')

ax.legend()

#5.Add a title and axes labels.
ax.set_title("PyBer Fare by Month")

ax.set_xlabel("Date")
ax.set_ylabel("Fare($)")

#6.Add a y-axis limit.
ax.set_ylim(0, 45)

#7.Add grid lines.
ax.grid()

# %% [markdown]
# # Create Bar Charts Using the MATLAB Approach
#
# Module 5.1.5

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Fev", "Mar", "Apr", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axid = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %% [markdown]
# ### Create a Vertical Bar Chart

# %%
# Create the plot
plt.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %% [markdown]
# ### Annotate the Vertical Bar Charts
#
# we won't need the marker or linewidth attributes.

# %%
# Create the plot.
plt.bar(x_axis, y_axis, color="green", label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %% [markdown]
# ## Create a Horizontal Bar Chart

# %%
# Create the plot
plt.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create a horizontal bar chart with the data on opposite axes. Switch the arguments in the barh() function
# Create the plot
plt.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
#invert the y-axis to have the months in ascending order.
# Create the plot.
plt.barh(x_axis, y_axis)
plt.gca().invert_yaxis()

# %% [markdown]
# ### Skill Drill
#
#
# Using the Matplotlib MATLAB plotting approach, make the following changes:
#
# Change the bar colors to magenta.
#
# Add a legend for the city of Boston.
#
# Add a title and axes labels.
#
# Invert the y-axis so that January is at the top.

# %%
# Create the plot.
plt.barh(x_axis, y_axis, color="magenta", label='Boston')

plt.gca().invert_yaxis()


# Create labels for the x and y axes.
plt.xlabel("Fare($)")
plt.ylabel("Date")

# Create a title.
plt.title("PyBer Fare by Month")

# Add the legend.
plt.legend()

# %% [markdown]
# # Create Bar Charts Using the Object-Oriented Approach
#
# Module 5.1.6

# %%
# Ride sharing data:
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %% [markdown]
# ## Create a Vertical Bar Chart

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %% [markdown]
# ### Exercise:
#
# Using the code we used to create the previous bar graph, how would you change the bar color to black with a legend for the city of New York using the object-oriented interface method?
#
# Answer:
#
# ax.bar(x_axis, y_axis, color="k", label='New York')
#
#
# ax.bar(x_axis, y_axis, color="black", label='New York')

# %%
# Create the plot using the object-oriented approach.

ax = plt.axes()
#1.Change the line color to green.
#2.Change the marker to a diamond.
#3.Change the line width to 2 points.
#4.Add a legend for the city of Boston.
ax.bar(x_axis, y_axis, color='black', label='New York')

ax.legend()

#5.Add a title and axes labels.
ax.set_title("PyBer Fare by Month")

ax.set_xlabel("Date")
ax.set_ylabel("Fare($)")

#6.Add a y-axis limit.
ax.set_ylim(0, 45)
# Out:
# (0.0, 45.0)

# %% [markdown]
# ## Create a Horizontal Bar Chart

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# If we want the data on opposite axes, we need to switch the arguments in the barh() function, as shown here:
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %% [markdown]
# ### Skill Drill
#
# Using the object-oriented approach, make the following changes:
#
# Change the bar color to cyan.
#
# Add a legend for the city of Chicago.
#
# Add a title and axes labels.
#
# Switch the axis so that the Fare($) data is on the x-axis.
#
# Invert the y-axis data.

# %%
ax = plt.axes()

# Change the bar color to cyan.
# Add a legend for the city of Chicago.
ax.barh(x_axis, y_axis, color="cyan", label='Chicago')


# Add a title and axes labels.
ax.set_title("PyBer Fare by Month")
ax.set_xlabel("Fare($)")
ax.set_ylabel("Date")


ax.legend()

ax.set_xlim(0, 45)


ax = plt.gca()
ax.invert_yaxis()

# %% [markdown]
# # Create Scatter Plots and Bubble Charts
# Module 5.1.7- Scatter plots have many benefits over line and bar charts. A scatter plot visually depicts a positive, negative, or no-correlation relationship between two factors.

# %% [markdown]
# ## Create a Scatter Plot Using the MATLAB Method
#
# There are two ways to create scatter plots using the MATLAB approach:
#
# plt.plot()
#
# plt.scatter()

# %% [markdown]
# ### plt.plot()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

plt.plot(x_axis, y_axis, 'o')

# %% [markdown]
# ### plt.scatter()

# %%
plt.scatter(x_axis, y_axis)

# %% [markdown]
# ### Skill Drill
#
# Using the Matplotlib MATLAB plotting approach, make the following changes to your scatter plot:
#
# Change the color of the markers to red.
#
# Add a legend for the city of Chicago.
#
# Add a title and axes labels.
#
# Switch the axis so that the Fare($) data is on the x-axis.
#
# Add a limit for the x-axis data.
#
# Invert the y-axis so that January is at the top.

# %%
#Create the scatter plot
#Change the color of the markers to red.
#Add a legend for the city of Chicago.
plt.scatter(y_axis, x_axis, color="red", label="Chicago")

#Add a title and axes labels.
#Switch the axis so that the Fare($) data is on the x-axis.
plt.title("PyBer Fare by Month")

plt.xlabel("Fare($)")
plt.ylabel("Date")

#Add a limit for the x-axis data.
plt.xlim(0, 50)

#Invert the y-axis so that January is at the top.

plt.gca().invert_yaxis()

# Add the legend.
plt.legend()

# %% [markdown]
# ## Create a Bubble Chart Using the MATLAB Method
#
# to change the size of our marker on the graph, we have to use the s, or size parameter, for the marker. The s parameter must be equal to a feature of our data. We will make the size of each marker equal to the data floating-point decimal values of the y-axis by using s=y_axis.

# %%
plt.scatter(x_axis, y_axis, s=y_axis)

# %%
# We can adjust the size by multiplying the data in the y-axis by any value.
# Let's multiply each data point in the y-axis by 3 and see what happens. 
y_axis_larger = []
for data in y_axis:
  y_axis_larger.append(data*3)

# %%
#Then we can use the new y-axis list for the s parameter:

plt.scatter(x_axis, y_axis, s=y_axis_larger)

# %% [markdown]
# ### Use list Comprehension to Refactor Code Above
#
# reafctor the code used to produce the scatter plto above, but instead of using a for loop to create the list y_axis_larger for the size parameter of the marker, we can use Python's list comprehension technique inside the plt.scatter() function. You can use list comprehension to replace many for and while loops. List comprehension is faster because it is optimized for Python to spot a predictable pattern during looping.
#
# The format for list comprehension is as follows:
# new_list = [expression for item in list if conditional]

# %%
# Using the list comprehension technique to multiply each data point in the y-axis list, 
# we would do the following in the plt.scatter() function:
plt.scatter(x_axis, y_axis, s = [i * 3 for i in y_axis])

# %% [markdown]
# ## Create a Scatter Plot Using the Object-Oriented Interface

# %%
# create plot
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis)

# %% [markdown]
# ## Create a Bubble Chart Using the Object-Oriented Interface

# %%
# create plot
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis, s=y_axis)

# %% [markdown]
# ### Skill Drill
#
# #### Using the object-oriented approach, make the following changes to your bubble chart:
#
#
# Change the color of the markers to sky blue.
#
# Change the size of the markers to 5 times each data point.
#
# Make the color 20% transparent.
#
# Add a black edge color to the circles.
#
# Make the linewidth of the circles 2 points.
#
# Add a legend for the city of Boston.
#
# Add a title.
#
# Switch the axis so that the Fare($) data is on the x-axis.
#
# Add a limit for the x-axis data.
#
# Invert the y-axis so that January is at the top.

# %%
# create plot
fig, ax = plt.subplots()

# Change the color of the markers to sky blue.
# Change the size of the markers to 5 times each data point.
# Make the color 20% transparent.
# Add a black edge color to the circles.
# Make the linewidth of the circles 2 points.
# Add a legend for the city of Boston.

ax.scatter(x_axis, y_axis,
           c="skyblue",
           s=[i * 5 for i in y_axis],
           alpha= 0.2,
           edgecolors="black",
           linewidth=2,
           label="Boston")

ax.legend()

#Add a title.
ax.set_title("PyBer Fare by Month")

#Switch the axis so that the Fare($) data is on the x-axis.
ax.set_xlabel("Fare($)")
ax.set_ylabel("Date")

#Add a limit for the x-axis data.
ax.set_ylim(0, 50)

#Invert the y-axis so that January is at the top.


ax = plt.gca()
ax.invert_yaxis()

# %% [markdown]
# # Create Pie Charts
#
# Module 5.1.8

# %% [markdown]
# ## Create a Pie Chart Using the MATLAB Method

# %%
plt.pie(y_axis, labels=x_axis)
plt.show()

# %% [markdown]
# Let's add percentages for each month and "explode" the largest percentage, which is July, the seventh value in the x_axis. The "explode" parameter will offset the indicated wedge by a fraction of the radius, where "0" is zero distance from the center of the pie, and "1" is completely outside the diameter of the pie.
#
# Let's break down what the graphing code is doing:
#
# To explode a pie wedge, we use array-like data points (like the tuple explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)) for each value in the pie chart.
# The length of the tuple should be equal to the number of wedges in the pie chart.
# The value specified to "explode" a wedge is the fraction of the radius from the center of the pie for each wedge.
# To pop out the seventh month, July, we use a decimal-point value of 0.2.
# To add the percentage of each wedge on the pie chart, we use the autopct parameter and provide the format of one decimal place using .1f%.
# The % before and after the .1f% formats the number as a percentage.
#
# as hown on the pie chart bellow:

# %% [markdown]
# The percentages on the pie chart seem a bit crowded. Let's increase the size of the pie chart by using plt.subplots(figsize=(8, 8)).

# %%
plt.subplots(figsize=(8, 8))
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%')
plt.show()

# %%
# Assign 12 colors, one for each month.
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.subplots(figsize=(8, 8))
plt.pie(y_axis,
    explode=explode_values,
    colors=colors,
    labels=x_axis,
    autopct='%.1f%%')

plt.show()

# %% [markdown]
# ## Create a Pie Chart Using the Object-Oriented Interface

# %%
fig, ax = plt.subplots()
ax.pie(y_axis,labels=x_axis)
plt.show()

# %% [markdown]
# ### Skill Drill
#
# #### Using the object-oriented approach, make the following changes to the pie chart:
#
#
# Add a percentage to one decimal place to each wedge of the pie.
#
# Increase the figure size to 8x8.
#
# Explode the two highest percentage months.
#
# Add a shadow.
#
# Add a start angle so that January is at the top.
#
# Reverse the order so that the month order is in a clockwise direction.
#
# Add new colors of your own choosing or use the colors from the previous pie chart.

# %%
fig, ax = plt.subplots(figsize=(8,8))

# Add new colors of your own choosing or use the colors from the previous pie chart.
colors = ["slateblue", "magenta", "lightblue", "green", 
          "yellowgreen", "greenyellow", "yellow", "orange", 
          "gold", "indianred", "tomato", "mistyrose"]

# Explode the two highest percentage months.
explode_values = (0, 0, 0.2, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)

# Add a percentage to one decimal place to each wedge of the pie.
# Add a shadow.
# Add a start angle so that January is at the top.
# Reverse the order so that the month order is in a clockwise direction.
# Add a percentage to one decimal place to each wedge of the pie.
plt.pie(y_axis,
       explode=explode_values,
       colors=colors,
       shadow=True,
       startangle=90,
       counterclock=False,
       labels=x_axis,
       autopct='%.1f%%')

plt.show()
